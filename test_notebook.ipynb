# %%
pip install streamlit
# Out:
# ...
#      |████████████████████████████████| 9.1 MB 6.0 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 982 kB 8.5 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 184 kB 10.0 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 24.8 MB 10.1 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 164 kB 12.3 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 477 kB 10.3 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 238 kB 15.5 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 4.8 MB 11.1 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 62 kB 4.4 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 84 kB 7.1 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 1.1 MB 10.1 MB/s eta 0:00:01
# ...
#   Created wheel for validators: filename=validators-0.20.0-py3-none-any.whl size=19583 sha256=cc6deab0579438eb7d69b45fb992bbdf073f0218fcd09dd4e0c4504b21f0209a
# ...
